# %% [markdown]
# <a href="https://colab.research.google.com/github/TuNguyen142/AL-13-2/blob/main/AL13_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
value1 = input ('nhap vao so thu 1')
# Out:
# nhap vao so thu 17

# %%
value2 = input ('Nhap vao so thu 2')
# Out:
# Nhap vao so thu 23

# %%
value1 + value2
# Out:
# '73'

# %%
value1 = int(value1)
value2 = int(value2)

# %%
#Write to file
with open('text.txt',mode ='w') as accounts:
    accounts.write('201461 Nguyen Van A 10\n');
    accounts.write('201462 Le Van B 6\n')
    accounts.write('201463 Tran Van C 8\n')

# %%
with open('text1.txt',mode ='w') as accounts:
  print('201461 Nguyen Van A', file = accounts)
  print('201462 Le Van B', file = accounts)
  print('201463 Tran Van C', file = accounts)

# %%
with open('text2.txt',mode = 'r') as accounts:
  print(f"{'MSSV':<10}{'Name':<20}{'Score':>2}")
  for record in accounts:
    mssv, name, score = record.split()
    print(f"{mssv:<10}{name:<20}{score:>2}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-8f1c5891abc8> in <module>
# ----> 1 with open('text2.txt',mode = 'r') as accounts:
#       2   print(f"{'MSSV':<10}{'Name':<20}{'Score':>2}")
#       3   for record in accounts:
#       4     mssv, name, score = record.split()
#       5     print(f"{mssv:<10}{name:<20}{score:>2}")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'text2.txt'

# %%
import pandas as pd
url = '/AL.csv'
dataframe = pd.read_csv(url)
dataframe.head(21)
# Out:
#     No     MSSV NAME KHOA  SCORE
# 0     1  201461    A  CKM      1
# 1     2  201462    B  CKM      2
# 2     3  201463    C  CKM      3
# 3     4  201464    D  CKM      4
# 4     5  201465    E  CKM      5
# 5     6  201466    F  CKM      6
# 6     7  201467    G  CKM      7
# 7     8  201468    H  CKM      8
# 8     9  201469    J  CKM      9
# 9    10  191461    K  CKM     10
# 10   11  191462    L  CKM      9
# 11   12  191463    Q  CKM      8
# 12   13  191464    W  CKM      7
# 13   14  191465    E  CKM      6
# 14   15  191466    R  CKM      5
# 15   16  191467    T  CKM      4
# 16   17  191468    Y  CKM      3
# 17   18  191469    U  CKM      2
# 18   19  181461    I  CKM      1
# 19   20  181462    U  CKM      0

# %%
dataframe.iloc[2]
# Out:
# No            3
# MSSV     201463
# NAME          C
# KHOA        CKM
# SCORE         3
# Name: 2, dtype: object

# %%
dataframe = dataframe.set_index(dataframe['NAME'])
dataframe.loc['T']
# Out:
# No           16
# MSSV     191467
# NAME          T
# KHOA        CKM
# SCORE         4
# Name: T, dtype: object

# %%
dataframe[dataframe['KHOA']=='CKM'].head(10)
# Out:
#       No     MSSV NAME KHOA  SCORE
# NAME
# A       1  201461    A  CKM      1
# B       2  201462    B  CKM      2
# C       3  201463    C  CKM      3
# D       4  201464    D  CKM      4
# E       5  201465    E  CKM      5
# F       6  201466    F  CKM      6
# G       7  201467    G  CKM      7
# H       8  201468    H  CKM      8
# J       9  201469    J  CKM      9
# K      10  191461    K  CKM     10

# %%
dataframe[(dataframe['KHOA']=='CKM')&(dataframe['NAME']=='T')]
# Out:
#       No     MSSV NAME KHOA  SCORE
# NAME
# T      16  191467    T  CKM      4

# %%
dataframe['KHOA'].replace('CKM','Co khi may').head(10)
# Out:
# NAME
# A    Co khi may
# B    Co khi may
# C    Co khi may
# D    Co khi may
# E    Co khi may
# F    Co khi may
# G    Co khi may
# H    Co khi may
# J    Co khi may
# K    Co khi may
# Name: KHOA, dtype: object

# %%
dataframe.replace('CKM','Co khi may').head(10)
# Out:
#       No     MSSV NAME        KHOA  SCORE
# NAME
# A       1  201461    A  Co khi may      1
# B       2  201462    B  Co khi may      2
# C       3  201463    C  Co khi may      3
# D       4  201464    D  Co khi may      4
# E       5  201465    E  Co khi may      5
# F       6  201466    F  Co khi may      6
# G       7  201467    G  Co khi may      7
# H       8  201468    H  Co khi may      8
# J       9  201469    J  Co khi may      9
# K      10  191461    K  Co khi may     10

# %%
print('Diem cao nhat',dataframe['SCORE'].max())
print('Diem thap nhat',dataframe['SCORE'].min())
print('Diem trung binh',dataframe['SCORE'].mean())
print('Diem TONG',dataframe['SCORE'].sum())
print('Bao nhieu Nguoi',dataframe['SCORE'].count())
# Out:
# Diem cao nhat 10
# Diem thap nhat 0
# Diem trung binh 5.0
# Diem TONG 100
# Bao nhieu Nguoi 20

# %%
dataframe['KHOA'].unique()
dataframe['KHOA'].value_counts()
# Out:
# CKM    20
# Name: KHOA, dtype: int64

# %%
dataframe.drop('MSSV',axis=1).head(10)
# Out:
#       No  NAME KHOA  SCORE
# NAME
# A       1    A  CKM      1
# B       2    B  CKM      2
# C       3    C  CKM      3
# D       4    D  CKM      4
# E       5    E  CKM      5
# F       6    F  CKM      6
# G       7    G  CKM      7
# H       8    H  CKM      8
# J       9    J  CKM      9
# K      10    K  CKM     10

# %%
dataframe.drop(['MSSV','KHOA'],axis=1).head(10)
# Out:
#       No  NAME  SCORE
# NAME
# A       1    A      1
# B       2    B      2
# C       3    C      3
# D       4    D      4
# E       5    E      5
# F       6    F      6
# G       7    G      7
# H       8    H      8
# J       9    J      9
# K      10    K     10

# %%
dataframe.drop(dataframe.columns[2:4],axis=1).head(10)
# Out:
#       No     MSSV  SCORE
# NAME
# A       1  201461      1
# B       2  201462      2
# C       3  201463      3
# D       4  201464      4
# E       5  201465      5
# F       6  201466      6
# G       7  201467      7
# H       8  201468      8
# J       9  201469      9
# K      10  191461     10

# %%
dataframe[dataframe['NAME']!='A'].head(10)
# Out:
#       No     MSSV NAME KHOA  SCORE
# NAME
# B       2  201462    B  CKM      2
# C       3  201463    C  CKM      3
# D       4  201464    D  CKM      4
# E       5  201465    E  CKM      5
# F       6  201466    F  CKM      6
# G       7  201467    G  CKM      7
# H       8  201468    H  CKM      8
# J       9  201469    J  CKM      9
# K      10  191461    K  CKM     10
# L      11  191462    L  CKM      9

# %%
dataframe[dataframe['SCORE']!=3].head(10)
# Out:
#       No     MSSV NAME KHOA  SCORE
# NAME
# A       1  201461    A  CKM      1
# B       2  201462    B  CKM      2
# D       4  201464    D  CKM      4
# E       5  201465    E  CKM      5
# F       6  201466    F  CKM      6
# G       7  201467    G  CKM      7
# H       8  201468    H  CKM      8
# J       9  201469    J  CKM      9
# K      10  191461    K  CKM     10
# L      11  191462    L  CKM      9

# %%
dataframe[dataframe.index!=4].head(10)
# Out:
#       No     MSSV NAME KHOA  SCORE
# NAME
# A       1  201461    A  CKM      1
# B       2  201462    B  CKM      2
# C       3  201463    C  CKM      3
# D       4  201464    D  CKM      4
# E       5  201465    E  CKM      5
# F       6  201466    F  CKM      6
# G       7  201467    G  CKM      7
# H       8  201468    H  CKM      8
# J       9  201469    J  CKM      9
# K      10  191461    K  CKM     10

# %%
dataframe.drop_duplicates().head(10)
# Out:
#       No     MSSV NAME KHOA  SCORE
# NAME
# A       1  201461    A  CKM      1
# B       2  201462    B  CKM      2
# C       3  201463    C  CKM      3
# D       4  201464    D  CKM      4
# E       5  201465    E  CKM      5
# F       6  201466    F  CKM      6
# G       7  201467    G  CKM      7
# H       8  201468    H  CKM      8
# J       9  201469    J  CKM      9
# K      10  191461    K  CKM     10

# %%
dataframe.groupby('KHOA').head(10)
# Out:
#       No     MSSV NAME KHOA  SCORE
# NAME
# A       1  201461    A  CKM      1
# B       2  201462    B  CKM      2
# C       3  201463    C  CKM      3
# D       4  201464    D  CKM      4
# E       5  201465    E  CKM      5
# F       6  201466    F  CKM      6
# G       7  201467    G  CKM      7
# H       8  201468    H  CKM      8
# J       9  201469    J  CKM      9
# K      10  191461    K  CKM     10

# %%
dataframe.groupby('KHOA').count()
# Out:
#       No   MSSV  NAME  SCORE
# KHOA
# CKM    20    20    20     20

# %%
dataframe.groupby(['KHOA','SCORE']).count
# Out:
# <bound method DataFrameGroupBy.count of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f08bfdb01f0>>

# %%
dataframe.groupby('KHOA')['SCORE'].count()
# Out:
# KHOA
# CKM    20
# Name: SCORE, dtype: int64

# %%
from pandas.core import resample
import pandas as pd
import numpy as np
time_index = pd.date_range('01/01/2023',periods = 100000, freq = '30s')
dataframe = pd.DataFrame(index = time_index)
dataframe['Acess_Amount'] = np.random.randint(1,10,100000)
dataframe.resample('W').sum()
# Out:
#             Acess_Amount
# 2023-01-01         14775
# 2023-01-08        100847
# 2023-01-15        100590
# 2023-01-22        100977
# 2023-01-29        100762
# 2023-02-05         83048

# %%
dataframe.resample('2W').mean()
dataframe.resample('M').mean()
# Out:
#             Acess_Amount
# 2023-01-31      5.007056
# 2023-02-28      5.034422

# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)

# %%
data.groupby('NOC')['Medal'].count()
# Out:
# NOC
# AUS      6
# AUT    185
# BEL      5
# BLR      6
# BUL      6
# CAN    119
# CHN     33
# CRO      7
# CZE     10
# DEN      1
# ESP      2
# EST      6
# EUA     19
# EUN     23
# FIN    151
# FRA     83
# FRG     41
# GBR     21
# GDR    110
# GER    158
# HUN      6
# ITA    101
# JPN     32
# KAZ      5
# KOR     31
# LAT      1
# LIE      9
# LUX      2
# NED     78
# NOR    280
# NZL      1
# POL      8
# PRK      2
# ROU      1
# RUS     76
# SLO      4
# SUI    118
# SVK      1
# SWE    118
# TCH     25
# UKR      5
# URS    194
# USA    216
# UZB      1
# YUG      4
# Name: Medal, dtype: int64

# %%
data.groupby('NOC')['Medal'].count()
# Out:
# NOC
# AUS      6
# AUT    185
# BEL      5
# BLR      6
# BUL      6
# CAN    119
# CHN     33
# CRO      7
# CZE     10
# DEN      1
# ESP      2
# EST      6
# EUA     19
# EUN     23
# FIN    151
# FRA     83
# FRG     41
# GBR     21
# GDR    110
# GER    158
# HUN      6
# ITA    101
# JPN     32
# KAZ      5
# KOR     31
# LAT      1
# LIE      9
# LUX      2
# NED     78
# NOR    280
# NZL      1
# POL      8
# PRK      2
# ROU      1
# RUS     76
# SLO      4
# SUI    118
# SVK      1
# SWE    118
# TCH     25
# UKR      5
# URS    194
# USA    216
# UZB      1
# YUG      4
# Name: Medal, dtype: int64

# %%
data[(data['NOC']== 'USA')&(data['Medal'])].value_counts()
# Out:
# Year  City         Sport       Discipline     NOC  Event            Event gender  Medal
# 1968  Grenoble     Skating     Speed skating  USA  500m             W             Silver    3
# 1948  St. Moritz   Skating     Speed skating  USA  500m             M             Silver    2
# 1924  Chamonix     Ice Hockey  Ice Hockey     USA  ice hockey       M             Silver    1
# 1998  Nagano       Skating     Speed skating  USA  1000m            W             Silver    1
# 1994  Lillehammer  Skiing      Alpine Skiing  USA  downhill         W             Silver    1
#                                                                                            ..
# 1972  Sapporo      Skating     Speed skating  USA  1000m            W             Bronze    1
#                                                    1500m            W             Gold      1
#                                                    3000m            W             Silver    1
# ...

# %%
data[(data['Medal'] == 'Gold')].value_counts()
# Out:
# Year  City               Sport     Discipline       NOC  Event                  Event gender  Medal
# 2002  Salt Lake City     Skiing    Cross Country S  NOR  10km pursuit           M             Gold     2
# 1956  Cortina d'Ampezzo  Skating   Speed skating    URS  1500m                  M             Gold     2
# 1924  Chamonix           Biathlon  Biathlon         SUI  military patrol        M             Gold     1
# 1994  Lillehammer        Skiing    Alpine Skiing    SWE  alpine combined        W             Gold     1
#                          Skating   Speed skating    USA  1000m                  W             Gold     1
#                                                                                                       ..
# 1972  Sapporo            Skiing    Ski Jumping      JPN  K90 individual (70m)   M             Gold     1
#                                                     POL  K120 individual (90m)  M             Gold     1
# ...
