# %% [markdown]
# <a href="https://colab.research.google.com/github/TuNguyen142/AL-13-2/blob/main/Al(13_3_2023).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = '/content/1.01. Simple linear regression.csv'
dataframe = pd.read_csv(url)
dataframe.head(21)
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# 5   1670  2.91
# 6   1764  3.00
# 7   1764  3.00
# 8   1792  3.01
# 9   1850  3.01
# 10  1735  3.02
# 11  1775  3.07
# 12  1735  3.08
# 13  1712  3.08
# 14  1773  3.12
# 15  1872  3.17
# 16  1755  3.17
# 17  1674  3.17
# 18  1842  3.17
# 19  1786  3.19
# 20  1761  3.19

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
url = '1.01. Simple linear regression.csv'
dataframe = pd.read_csv(url)
dataframe.head(21)
x1 = np.arange(1700,2100,1)
y = np.arange(1700,2100,1)
plt.scatter(x1,y)
plt.xlabel('SAT', fontsize=20)
plt.ylabel('GPA', fontsize=20)
plt.show()

# %%
from sklearn import linear_model_
regression_model = linear_model.LinearRegression
regression_model.fit(x1,y)
print(regression_model.intercept)
print(regression_model.coef)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-30-83de80b56340> in <module>
# ----> 1 from sklearn import linear_model_
#       2 regression_model = linear_model.LinearRegression
#       3 regression_model.fit(x1,y)
#       4 print(regression_model.intercept)
#       5 print(regression_model.coef)
#
# ImportError: cannot import name 'linear_model_' from 'sklearn' (/usr/local/lib/python3.9/dist-packages/sklearn/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
a = 'mtcars.csv'
data = pd.read_csv(a)
data.head()
data.shape
data.plot()
b = data.corr()
print(b)
x = data.drop(data.columns[[0,2]],axis =1)
data.plot(kind = 'scatter',x = 'wt',y = 'mpg',figsize = (9,9),color = 'black')
# Out:
#            mpg      disp        hp        wt
# mpg   1.000000 -0.847551 -0.776168 -0.867659
# disp -0.847551  1.000000  0.790949  0.887980
# hp   -0.776168  0.790949  1.000000  0.658748
# wt   -0.867659  0.887980  0.658748  1.000000
# <AxesSubplot:xlabel='wt', ylabel='mpg'>

# %%
from pandas._libs.tslibs import conversion
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model


model = linear_model.LinearRegression()
model.fit( X = pd.DataFrame(data ['wt']),y = data['mpg'])
print(model.intercept_)
print(model.coef_)

model.score( X = pd.DataFrame(data ['wt']),y= data['mpg'] )

y_pred = model.predict(X = pd.DataFrame(data ['wt']))
residual = data['mpg']-y_pred
residual.describe()

data.plot(kind = 'scatter',x = 'wt',y = 'mpg',figsize = (9,9),color = 'black')
plt.plot(data['wt'],y_pred, color = 'blue')
# Out:
# 37.28512616734204
# [-5.34447157]

# %%
model=linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2]).T
model.fit(X,y=data['mpg'])
print('Intercept cua mo hinh bac 2')
print(model.intercept_)
print('Cosfficent cua mo hinh bac 2')
print(model.coef_)
print('Do chinh xac cua mo hinh')
print(model.score(X,y =data['mpg']))
# Out:
# Intercept cua mo hinh bac 2
# 49.93081094945181
# Cosfficent cua mo hinh bac 2
# [-13.38033708   1.17108689]
# Do chinh xac cua mo hinh
# 0.8190613581384094

# %%
range=np.arange(1.5,5.5,0.1)
predictor=pd.DataFrame([range,range**2]).T
y_pred=model.predict(X=predictor)
data.plot(kind ='scatter',x='wt',y='mpg',figsize=(9,9),color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
model=linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2]).T
model.fit(X,y=data['mpg'])
print('Intercept cua mo hinh bac 2')
print(model.intercept_)
print('Cosfficent cua mo hinh bac 2')
print(model.coef_)
print('Do chinh xac cua mo hinh')
print(model.score(X,y =data['mpg']))
range=np.arange(1.5,5.5,0.1)
predictor=pd.DataFrame([range,range**2]).T
y_pred=model.predict(X=predictor)
data.plot(kind ='scatter',x='wt',y='mpg',figsize=(9,9),color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# Intercept cua mo hinh bac 2
# 49.93081094945181
# Cosfficent cua mo hinh bac 2
# [-13.38033708   1.17108689]
# Do chinh xac cua mo hinh
# 0.8190613581384094
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from pandas._libs.tslibs import conversion
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model


model = linear_model.LinearRegression()
model.fit( X = pd.DataFrame(data ['wt']),y = data['mpg'])
print(model.intercept_)
print(model.coef_)

model.score( X = pd.DataFrame(data ['wt']),y= data['mpg'] )

y_pred = model.predict(X = pd.DataFrame(data ['wt']))
residual = data['mpg']-y_pred
residual.describe()

data.plot(kind = 'scatter',x = 'wt',y = 'mpg',figsize = (9,9),color = 'black')
plt.plot(data['wt'],y_pred, color = 'blue')
model=linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**2]).T
model.fit(X,y=data['mpg'])
print('Intercept cua mo hinh bac 2')
print(model.intercept_)
print('Cosfficent cua mo hinh bac 2')
print(model.coef_)
print('Do chinh xac cua mo hinh')
print(model.score(X,y =data['mpg']))
range=np.arange(1.5,5.5,0.1)
predictor=pd.DataFrame([range,range**2]).T
y_pred=model.predict(X=predictor)
data.plot(kind ='scatter',x='wt',y='mpg',figsize=(9,9),color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# 37.28512616734204
# [-5.34447157]
# Intercept cua mo hinh bac 2
# 49.93081094945181
# Cosfficent cua mo hinh bac 2
# [-13.38033708   1.17108689]
# Do chinh xac cua mo hinh
# 0.8190613581384094
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from pandas._libs.tslibs import conversion
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model


model = linear_model.LinearRegression()
model.fit( X = pd.DataFrame(data ['wt']),y = data['mpg'])
print(model.intercept_)
print(model.coef_)

model.score( X = pd.DataFrame(data ['wt']),y= data['mpg'] )

y_pred = model.predict(X = pd.DataFrame(data ['wt']))
residual = data['mpg']-y_pred
residual.describe()

data.plot(kind = 'scatter',x = 'wt',y = 'mpg',figsize = (9,9),color = 'black')
plt.plot(data['wt'],y_pred, color = 'blue')
model=linear_model.LinearRegression()
X = pd.DataFrame([data['wt'],data['wt']**10]).T
model.fit(X,y=data['mpg'])
print('Intercept cua mo hinh bac 10')
print(model.intercept_)
print('Cosfficent cua mo hinh bac 10')
print(model.coef_)
print('Do chinh xac cua mo hinh')
print(model.score(X,y =data['mpg']))
range=np.arange(1.5,5.5,0.1)
predictor=pd.DataFrame([range,range**10]).T
y_pred=model.predict(X=predictor)
data.plot(kind ='scatter',x='wt',y='mpg',figsize=(9,9),color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# 37.28512616734204
# [-5.34447157]
# Intercept cua mo hinh bac 10
# 41.668286276063
# Cosfficent cua mo hinh bac 10
# [-6.94137737e+00  3.80611877e-07]
# Do chinh xac cua mo hinh
# 0.8115722747386714
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
data=pd.read_csv('50_Startups.csv')
data.head()
sns.pairplot(data)
corr=data.corr()
# Out:
#    R&D Spend  Administration  Marketing Spend       State
# 0  165349.20       136897.80        471784.10    New York
# 1  162597.70       151377.59        443898.53  California
# 2  153441.51       101145.55        407934.54     Florida
# 3  144372.41       118671.85        383199.62    New York
# 4  142107.34        91391.77        366168.42     Florida

# %%
sns.heatmap(corr,annot=True)
X=data.drop('Profit',axis=True)
y=data['Profit']
X.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State
# 0  165349.20       136897.80        471784.10    New York
# 1  162597.70       151377.59        443898.53  California
# 2  153441.51       101145.55        407934.54     Florida
# 3  144372.41       118671.85        383199.62    New York
# 4  142107.34        91391.77        366168.42     Florida

# %%
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
corr = data.corr()
sns.heatmap(corr,annot = True)
# Out:
# <AxesSubplot:>

# %%
X = data.drop(['State','Profit'],axis=True)
y = data['Profit']
X.head()
# Out:
#    R&D Spend  Administration  Marketing Spend
# 0  165349.20       136897.80        471784.10
# 1  162597.70       151377.59        443898.53
# 2  153441.51       101145.55        407934.54
# 3  144372.41       118671.85        383199.62
# 4  142107.34        91391.77        366168.42

# %%
sc = StandardScaler()
X = sc.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=0)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (40, 3)
# (10, 3)
# (40,)
# (10,)

# %%
regression = linear_model.LinearRegression()
regression.fit(X_train, y_train)
y_pred = regression.predict(X_test.round(1))
calculation = pd.DataFrame(np.c_[y_test,y_pred],columns=['Original Profit','Predicted Profit'])
print(regression.score(X_train,y_train))
print(regression.score(X_test,y_test))
# Out:
# 0.9499572530324031
# 0.939395591782057
